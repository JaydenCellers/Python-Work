# %% [markdown]
# # Subplots Functionality and Styling

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.linspace(0,10,11)
b = a ** 4

# %%
x = np.arange(0,10)
y = 2*x

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
axes[0,1].plot(x,y)
axes[1][1].plot(a,b)

axes[1,1].set_title('1,1 Title')
fig.suptitle('Super Title')

plt.tight_layout()

#fig.subplots_adjust(wspace=0.5)

# %% [markdown]
# # Styling

# %%
z = np.linspace(0,11,10)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x, label='X vs, X')
ax.plot(x, x**2, label = 'X vs X^2')
ax.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x, color ='#12F356', lw = 2, marker = 'o')
